# %%
library(readxl)
Casas <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/Casas.xlsx")

# %%
#-----Exemplo 1 de Correlação------
r1 <- cor(Casas$Preco_Anunciado, Casas$Idade)
r1
plot(Casas$Preco_Anunciado, Casas$Idade)
# Out:
# [1] -0.4928441
# plot without title

# %%
#-----Exemplo 2 de Correlação-----
r2<- cor(Casas$Preco_Anunciado, Casas$Area_Util)
r2
plot(Casas$Preco_Anunciado, Casas$Area_Util)
# Out:
# [1] 0.8083902
# plot without title

# %%
#----Teste de Correlação Linear----
teste1 <- cor.test(Casas$Preco_Anunciado, Casas$Idade)
teste1
teste2 <- cor.test(Casas$Preco_Anunciado, Casas$Area_Util)
teste2
# Out:
# 	Pearson's product-moment correlation
#
# data:  Casas$Preco_Anunciado and Casas$Idade
# t = -3.4916, df = 38, p-value = 0.001234
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  -0.6973000 -0.2142235
# sample estimates:
#        cor
# -0.4928441
# 	Pearson's product-moment correlation
#
# data:  Casas$Preco_Anunciado and Casas$Area_Util
# t = 8.4656, df = 38, p-value = 2.821e-10
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.6641203 0.8946163
# sample estimates:
#       cor
# 0.8083902

# %%
#----Exemplo 1 de Regressão----
r1 <- cor(Casas$Idade, Casas$Preco_Anunciado)
r1
plot(Casas$Idade, Casas$Preco_Anunciado)
ajuste <- lm(Preco_Anunciado ~ Idade, data = Casas)
summary(ajuste)
lines(Casas$Idade, ajuste$fitted.values, col = 2)
# Out:
# [1] -0.4928441
# Call:
# lm(formula = Preco_Anunciado ~ Idade, data = Casas)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -110.28  -58.76  -24.31   39.81  192.44
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 419.2104    23.0788  18.164  < 2e-16 ***
# Idade        -1.8170     0.5204  -3.492  0.00123 **
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 74.57 on 38 degrees of freedom
# Multiple R-squared:  0.2429,	Adjusted R-squared:  0.223
# F-statistic: 12.19 on 1 and 38 DF,  p-value: 0.001234
# plot without title

# %%
#----Exemplo 2 de Regressão----
r2<- cor(Casas$Area_Util, Casas$Preco_Anunciado)
r2
plot(Casas$Area_Util, Casas$Preco_Anunciado)
ajuste <- lm(Preco_Anunciado ~ Area_Util, data = Casas)
summary(ajuste)
lines(Casas$Area_Util, ajuste$fitted.values, col = 2)
# Out:
# [1] 0.8083902
# Call:
# lm(formula = Preco_Anunciado ~ Area_Util, data = Casas)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -87.726 -28.780  -6.163  13.784 137.045
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)  135.997     26.501   5.132 8.79e-06 ***
# Area_Util     12.042      1.422   8.466 2.82e-10 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 50.45 on 38 degrees of freedom
# Multiple R-squared:  0.6535,	Adjusted R-squared:  0.6444
# F-statistic: 71.67 on 1 and 38 DF,  p-value: 2.821e-10
# plot without title

# %%
#----Exemplo de Regressão Múltipla----
attach(Casas)
ajuste_multi <- lm(Preco_de_Venda ~ Area_Util + Idade + Comodos)
summary(ajuste_multi)
# Out:
# The following objects are masked from Casas (pos = 3):
#
#     Area_Util, Banheiros, Comodos, Idade, Preco_Anunciado,
#     Preco_de_Venda, Quartos, Terreno
#
# The following objects are masked from Casas (pos = 4):
#
#     Area_Util, Banheiros, Comodos, Idade, Preco_Anunciado,
#     Preco_de_Venda, Quartos, Terreno
#
# The following objects are masked from Casas (pos = 5):
#
#     Area_Util, Banheiros, Comodos, Idade, Preco_Anunciado,
#     Preco_de_Venda, Quartos, Terreno
#
# The following objects are masked from Casas (pos = 6):
#
#     Area_Util, Banheiros, Comodos, Idade, Preco_Anunciado,
#     Preco_de_Venda, Quartos, Terreno
#
# The following objects are masked from Casas (pos = 7):
#
#     Area_Util, Banheiros, Comodos, Idade, Preco_Anunciado,
#     Preco_de_Venda, Quartos, Terreno
#
# The following objects are masked from Casas (pos = 10):
#
#     Area_Util, Banheiros, Comodos, Idade, Preco_Anunciado,
#     Preco_de_Venda, Quartos, Terreno
# Call:
# lm(formula = Preco_de_Venda ~ Area_Util + Idade + Comodos)
#
# Residuals:
#    Min     1Q Median     3Q    Max
# -98.50 -22.87 -10.61  12.77 148.35
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 229.3998    51.0557   4.493 6.99e-05 ***
# Area_Util    12.7848     2.3721   5.390 4.55e-06 ***
# Idade        -0.9202     0.3827  -2.405   0.0215 *
# Comodos     -10.2639     8.5965  -1.194   0.2403
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 47.97 on 36 degrees of freedom
# Multiple R-squared:  0.6934,	Adjusted R-squared:  0.6679
# F-statistic: 27.14 on 3 and 36 DF,  p-value: 2.356e-09

# %%
#install.packages("car")
library(car)
vif(ajuste_multi)

#install.packages("MASS")
library(MASS)
stepAIC(ajuste_multi, direction = "both")
# Out:
# Area_Util     Idade   Comodos
#  3.075351  1.306848  3.429038
# package 'MASS' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'MASS'"
# The downloaded binary packages are in
# 	C:\Users\clmo\AppData\Local\Temp\RtmpIj7nOq\downloaded_packages
# Error in library(MASS): there is no package called 'MASS'
# Traceback:
#
# 1. library(MASS)

# %%
library(readxl)
RLS_BEZERRO <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/RLS BEZERRO.xlsx")

#----Exemplo Geral Regressão Linear Simples----
attach(RLS_BEZERRO)
plot(`Medida(CM)`,`Peso (KG)`, pch = 19, col = "Dark Blue", main = "Medida x Peso",
     cex.axis = 1.5, cex.main = 1.5, cex.lab = 1.5, cex = 1.5)
cor.test(`Medida(CM)`,`Peso (KG)`)
ajuste <- lm(`Peso (KG)` ~ `Medida(CM)`)
summary(ajuste)
boxplot(`Medida(CM)`, col = "Light Blue", main = "Box Plot Medida (CM)",
        cex.axis = 1.5, cex.main = 1.5, cex.lab = 1.5)
boxplot(`Peso (KG)`, col = "Light Green", main = "Box Plot Peso (KG)",
        cex.axis = 1.5, cex.main = 1.5, cex.lab = 1.5)
RLS_BEZERRO$Z_Medida <- scale(`Medida(CM)`)
RLS_BEZERRO$Z_Peso <- scale(`Peso (KG)`)
range(RLS_BEZERRO$Z_Medida)
range(RLS_BEZERRO$Z_Peso)
par(mfrow=c(2,2))
plot(ajuste)
# Out:
# 	Pearson's product-moment correlation
#
# data:  Medida(CM) and Peso (KG)
# t = 12.236, df = 43, p-value = 1.342e-15
# alternative hypothesis: true correlation is not equal to 0
# 95 percent confidence interval:
#  0.7930667 0.9334432
# sample estimates:
#       cor
# 0.8814144
# Call:
# lm(formula = `Peso (KG)` ~ `Medida(CM)`)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -6.9876 -3.2912 -0.4855  3.0227  8.6307
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    2.7893     5.4299   0.514     0.61
# `Medida(CM)`   2.7012     0.2207  12.236 1.34e-15 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 4.426 on 43 degrees of freedom
# Multiple R-squared:  0.7769,	Adjusted R-squared:  0.7717
# F-statistic: 149.7 on 1 and 43 DF,  p-value: 1.342e-15
# Plot with title "Medida x Peso"
# Plot with title "Box Plot Medida (CM)"
# [1] -1.824839  2.112314
# [1] -2.098742  1.906573
# Plot with title "Box Plot Peso (KG)"
# Plot with title ""

# %%
library(readxl)
HOUSES_EUA <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/HOUSES_EUA.xlsx")

#----Exemplo Geral Regressão Linear Composta----
attach(HOUSES_EUA)
#install.packages("PerformanceAnalytics")
library(PerformanceAnalytics)
HOUSES_Numeric <- HOUSES_EUA[,-2]
HOUSES_Numeric <- HOUSES_Numeric[,-4]
chart.Correlation(HOUSES_Numeric)
ajuste <- lm(Preco ~ Ofertas + `Tamanho (pes)` + Quartos + Banheiros + factor(Bairro) + Feita_tijolos)
summary(ajuste)
#install.packages("car")
library(car)
vif(ajuste)
#install.packages("MASS")
library(MASS)
stepAIC(ajuste, direction = "both")
par(mfrow=c(2,2))
plot(ajuste)
# Out:
# The following objects are masked from HOUSES_EUA (pos = 6):
#
#     Bairro, Banheiros, Feita_tijolos, Ofertas, Preco, Quartos, Tamanho
#     (pes)
#
# The following objects are masked from Casas (pos = 8):
#
#     Banheiros, Quartos
#
# The following objects are masked from Casas (pos = 9):
#
#     Banheiros, Quartos
#
# The following objects are masked from Casas (pos = 10):
#
#     Banheiros, Quartos
#
# The following objects are masked from Casas (pos = 11):
#
#     Banheiros, Quartos
#
# The following objects are masked from Casas (pos = 12):
#
#     Banheiros, Quartos
#
# The following objects are masked from Casas (pos = 13):
#
#     Banheiros, Quartos
#
# The following objects are masked from Casas (pos = 16):
#
#     Banheiros, Quartos
# Call:
# lm(formula = Preco ~ Ofertas + `Tamanho (pes)` + Quartos + Banheiros +
#     factor(Bairro) + Feita_tijolos)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -27337.3  -6549.5    -41.7   5803.4  27359.3
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)       2159.498   8877.810   0.243  0.80823
# Ofertas          -8267.488   1084.777  -7.621 6.47e-12 ***
# `Tamanho (pes)`     52.994      5.734   9.242 1.10e-15 ***
# Quartos           4246.794   1597.911   2.658  0.00894 **
# Banheiros         7883.278   2117.035   3.724  0.00030 ***
# factor(Bairro)2  -1560.579   2396.765  -0.651  0.51621
# factor(Bairro)3  20681.037   3148.954   6.568 1.38e-09 ***
# Feita_tijolosYes 17297.350   1981.616   8.729 1.78e-14 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 10020 on 120 degrees of freedom
# Multiple R-squared:  0.8686,	Adjusted R-squared:  0.861
# F-statistic: 113.3 on 7 and 120 DF,  p-value: < 2.2e-16
# also installing the dependency 'MASS'
#
# Warning message:
# "package 'car' is in use and will not be installed"
# package 'MASS' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'MASS'"
# The downloaded binary packages are in
# 	C:\Users\clmo\AppData\Local\Temp\RtmpIj7nOq\downloaded_packages
#                 GVIF     Df GVIF^(1/(2*Df))
# Ofertas         1.702392 1  1.304757
# `Tamanho (pes)` 1.862215 1  1.364630
# Quartos         1.702472 1  1.304788
# Banheiros       1.500976 1  1.225143
# factor(Bairro)  2.129593 2  1.208020
# Feita_tijolos   1.103908 1  1.050670
# package 'MASS' successfully unpacked and MD5 sums checked
# Warning message:
# "cannot remove prior installation of package 'MASS'"
# The downloaded binary packages are in
# 	C:\Users\clmo\AppData\Local\Temp\RtmpIj7nOq\downloaded_packages
# Error in library(MASS): there is no package called 'MASS'
# Traceback:
#
# 1. library(MASS)
# Plot with title ""

# %%
ajuste <- lm(scale(Preco) ~ Ofertas + scale(`Tamanho (pes)`) + Quartos + Banheiros + factor(Bairro) + Feita_tijolos)
summary(ajuste)
vif(ajuste)
stepAIC(ajuste, direction = "both")
par(mfrow=c(2,2))
plot(ajuste)
# Out:
# Call:
# lm(formula = scale(Preco) ~ Ofertas + scale(`Tamanho (pes)`) +
#     Quartos + Banheiros + factor(Bairro) + Feita_tijolos)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -1.01744 -0.24376 -0.00155  0.21599  1.01826
#
# Coefficients:
#                        Estimate Std. Error t value Pr(>|t|)
# (Intercept)            -0.82738    0.24895  -3.323  0.00118 **
# Ofertas                -0.30770    0.04037  -7.621 6.47e-12 ***
# scale(`Tamanho (pes)`)  0.41729    0.04515   9.242 1.10e-15 ***
# Quartos                 0.15806    0.05947   2.658  0.00894 **
# Banheiros               0.29340    0.07879   3.724  0.00030 ***
# factor(Bairro)2        -0.05808    0.08920  -0.651  0.51621
# factor(Bairro)3         0.76971    0.11720   6.568 1.38e-09 ***
# Feita_tijolosYes        0.64377    0.07375   8.729 1.78e-14 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.3729 on 120 degrees of freedom
# Multiple R-squared:  0.8686,	Adjusted R-squared:  0.861
# F-statistic: 113.3 on 7 and 120 DF,  p-value: < 2.2e-16
#                        GVIF     Df GVIF^(1/(2*Df))
# Ofertas                1.702392 1  1.304757
# scale(`Tamanho (pes)`) 1.862215 1  1.364630
# Quartos                1.702472 1  1.304788
# Banheiros              1.500976 1  1.225143
# factor(Bairro)         2.129593 2  1.208020
# Feita_tijolos          1.103908 1  1.050670
# Error in stepAIC(ajuste, direction = "both"): não foi possível encontrar a função "stepAIC"
# Traceback:

# %%
#----Exemplo 1 Regressão Logística Simples----
attach(Experiencia_Tarefa)
ajuste <- glm(Tarefa_concluidda ~ Experiencia, family = binomial)
summary(ajuste)
anova(ajuste, test = 'Chisq')
require(MASS)
exp(cbind(coef(ajuste), confint.default(ajuste)))
install.packages('pscl')
library(pscl)
pR2(ajuste)
plot(Experiencia_Tarefa)
y_chapeu <- data.frame(X = Experiencia_Tarefa$Experiencia, y_chapeu = ajuste$fitted.values)
y_chapeu <- y_chapeu[order(y_chapeu$X),]
lines(y_chapeu, col = 2)
y_chapeu
par(mfrow=c(2,2))
plot(ajuste)
y_chapeu <- data.frame(X = Experiencia_Tarefa$Experiencia, y_chapeu = ajuste$fitted.values)
y_chapeu$conclusão <- ifelse(y_chapeu$y_chapeu > .5, 1, 0)
y_chapeu$y <- Tarefa_concluidda
table(y_chapeu[,3:4])
mean(y_chapeu$conclusão == y_chapeu$y)
# Out:
# Error in attach(Experiencia_Tarefa): objeto 'Experiencia_Tarefa' não encontrado
# Traceback:
#
# 1. attach(Experiencia_Tarefa)

# %%
predicao <- data.frame(Peso_previsto = c(20, 28))
coef_ajuste <- coefficients(ajuste)
predicao$Peso_Previsto <- coef_ajuste[1]+coef_ajuste[2]*predicao
colnames(predicao) <- c("Medida", "Peso_previsto")
predicao
# Out:
# ERROR while rich displaying an object: Error in vapply(part, format, character(nrow(part))): valores devem ser de comprimento 2,
#  mas o resultado de FUN(X[[2]]) tem comprimento 1
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_text.data.frame(obj)
# 9. ellip_limit_arr(obj, ...)
# 10. arr_parts_format(parts)
# 11. structure(lapply(parts, arr_part_format), omit = attr(parts,
#   .     "omit"))
# 12. lapply(parts, arr_part_format)
# 13. FUN(X[[i]], ...)
# 14. vapply(part, format, character(nrow(part)))

# %%
#----Exemplo 2 Regressão Logística Composta----
library(readxl)
Lasagna_Triers <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/Lasagna Triers.xlsx")
View(Lasagna_Triers)
attach(Lasagna_Triers)
Lasagna_Triers$Compra <- ifelse(Lasagna_Triers$`Have Tried`=="Yes", 1, 0)
ajuste <- glm(Compra ~ Age + Weight + Income + `Pay Type` +
                `Car Value` + `CC Debt` + Gender + `Live Alone` +
                `Dwell Type` + `Mall Trips` + Nbhd, family = binomial)
summary(ajuste)
require(MASS)
stepAIC(ajuste, direction = "both")
ajuste2 <- glm(Compra ~ Age + `Pay Type` + Gender + `Live Alone` + 
                 `Mall Trips` + Nbhd, family = binomial)
summary(ajuste2)
exp(cbind(coef(ajuste2), confint.default(ajuste2)))
pchisq(ajuste2$deviance, ajuste2$df.residual, lower.tail = F) #Teste Chi-quadrado do Deviance
pchisq(ajuste2$null.deviance - ajuste2$deviance,
       ajuste2$df.null - ajuste$df.residual, lower.tail = F) #Teste Chi-quadrado da Regressão
library(car)
vif(ajuste2)
install.packages('pscl')
library(pscl)
pR2(ajuste2)
par(mfrow=c(2,2))
plot(ajuste2)
coef2 <- data.frame(coef(ajuste2))
p_hat <- (exp(coef2[1,] + coef2[2,]*20 + coef2[3,] + coef2[4,] +
              coef2[5,] + coef2[6,]*10 + coef2[8,]))/
          (1+exp(coef2[1,] + coef2[2,]*20 + coef2[3,] + coef2[4,] +
             coef2[5,] + coef2[6,]*10 + coef2[8,]))
p_hat
# Out:
# Error in View(Lasagna_Triers): 'View()' not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(Lasagna_Triers)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %%
#----Exemplo Análise Fatorial----
library(readxl)
EFA <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/EFA.xlsx")
View(EFA)
install.packages('psych')
install.packages('GPArotation')
library(psych)
library(GPArotation)
parallel <- fa.parallel(EFA, fm = 'pa', fa = 'fa') #escolha do número de fatores
tresfatores <- fa(EFA, nfactors = 3, rotate = "oblimin", fm="pa")
tresfatores
print(tresfatores$loadings, cutoff = .3)
quatrofatores <- fa(EFA, nfactors = 4, rotate = "oblimin", fm="pa")
quatrofatores
print(quatrofatores$loadings, cutoff = .3)
fa.diagram(quatrofatores)
# Out:
# Error in View(EFA): 'View()' not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(EFA)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %%
#----Exemplo Análise de Cluster----
library(readxl)
Proteina <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/Protein.xlsx")
View(Proteina)
install.packages("cluster")
library(cluster)
hc <- hclust(dist(Proteina[,-1]), method = 'average') 
plot(hc)
clusterCut <- cutree(hc, 3)
rect.hclust(hc, k=3, border="red")
clusplot(Proteina[,-1], clusterCut,
         main='Represetação Gráfica 2D - Solução com 3 Clusters',
         color=TRUE, shade=TRUE, labels=2, lines=0)
Proteina$Grupos <- clusterCut
Grupo_ordenado <- Proteina[order(Proteina$Grupos),]
somente_grupo <- subset(Grupo_ordenado,select = c(Country, Grupos))
View(somente_grupo)
# Out:
# Error in View(Proteina): 'View()' not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(Proteina)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %%
#----Exemplo Análise Discriminante----
library(readxl)
Candidatos <- read_excel("C:/Users/clmo/Documents/Estudos/PUC/05. Estatistica II/data/Candidatos.xlsx")
View(Candidatos)
ds_candidatos <- Candidatos[,-1]
View(ds_candidatos)
ds_candidatos$Grupo <- factor(ds_candidatos$Grupo, levels = c(1, 2, 3),
                              labels = c("Aprovado", "Espera", "Reprovado"))
View(ds_candidatos)
attach(ds_candidatos)
require(MASS)
install.packages("klaR")
library(klaR)
ajuste <- lda(Grupo ~ Nota_tecnica + Historico)
ajuste
plot(ajuste, col = as.integer(Grupo), cex = 1.5)
table(Grupo, Predito = predict(ajuste, Candidatos[,3:4])$class)
mean(Grupo == predict(ajuste, Candidatos[,3:4])$class)
partimat(Grupo ~ Nota_tecnica + Historico, method="lda")
plot(ajuste, dimen = 1, type = "b")

ajuste2 <- qda(Grupo ~ Nota_tecnica + Historico)
ajuste2
table(Grupo, Predito = predict(ajuste2, Candidatos[,3:4])$class)
mean(Grupo == predict(ajuste2, Candidatos[,3:4])$class)
partimat(Grupo ~ Nota_tecnica + Historico, method="qda")
# Out:
# Error in View(Candidatos): 'View()' not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(Candidatos)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %%
#----Exemplo de Análise de Séries Temporais----
data("AirPassengers")
View(AirPassengers)
plot(AirPassengers)
boxplot(AirPassengers~cycle(AirPassengers))
acf(AirPassengers)
pacf(AirPassengers)
#plot(decompose(AirPassengers))
plot(log(AirPassengers))
acf(log(AirPassengers))
pacf(log(AirPassengers))
plot(diff(log(AirPassengers)))
acf(diff(log(AirPassengers)))
pacf(diff(log(AirPassengers)))
install.packages("tseries")
library(tseries)
adf.test(diff(log(AirPassengers)), alternative="stationary", k=0)
ajuste <- arima(log(AirPassengers), c(0, 1, 1), seasonal = list(order = c(0, 1, 1), period = 12))
pred <- predict(ajuste, n.ahead = 10*12)
ts.plot(AirPassengers,exp(pred$pred), log = "y", lty = c(1,3))
ts.plot(AirPassengers,exp(pred$pred), lty = c(1,3))
# Out:
# Error in View(AirPassengers): 'View()' not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(AirPassengers)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")
